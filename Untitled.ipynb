# %%
import pandas as pd

# %%
customer_data_path = "CUSTOMERS.csv"

# %%
customer_data = pd.read_csv(customer_data_path)
customer_data.head()
# Out:
#      RECID             SHORT_NAME  GENDER         SMS_1  \
# 0  1000001          FURAHA PASCAL    MALE  250788301519
# 1  1000002        NYAMASWA EUGENE    MALE  250786661780
# 2  1000003    AYINKAMIYE FELICITE  FEMALE  250783168211
# 3  1000003      FLICIT AYINKAMIYE  FEMALE  250783168211
# 4  1000004  MUKAKIMENYI EPIPHANIE  FEMALE  250788523651
#
#                    EMAIL_1                     SECTOR  \
# 0    furahapascal@yahoo.fr  R&SME - Small Enterprises
# 1  nyamaswaeugene@yahoo.fr                R&SME INDIV
# 2                      NaN                R&SME INDIV
# 3                      NaN                R&SME INDIV
# 4   emukakimenyi@gmail.com                R&SME INDIV
#
#                               INDUSTRY MARITAL_STATUS  TARGET  \
# 0   Financial and insurance activities        MARRIED      64
# 1  Accommodation and food service acti        MARRIED      73
# 2             Other service activities        MARRIED      71
# ...

# %%
customer_data.shape
# Out:
# (23422, 17)

# %%
recommend_data_path = "recommend_data.csv"

# %%
recommend_data = pd.read_csv(recommend_data_path)
recommend_data.head()
# Out:
#    Unnamed: 0  CUSTOMER_ID                   DESCRIPTION  GENDER  \
# 0           0      1000764  AC Corporate Current Account  Others
# 1           1      1001468  AC Corporate Current Account  Others
# 2           2      1006782  AC Corporate Current Account  Others
# 3           3      1011339  AC Corporate Current Account  Others
# 4           4      1015944  AC Corporate Current Account  Others
#
#   MARITAL_STATUS                     SECTOR                    INDUSTRY  \
# 0         Others                 SSA - RSSB    Other service activities
# 1         Others                CA -Offices    Other service activities
# 2         Others           micro enterprise  Transportation and storage
# 3         Others  R&SME - Small Enterprises    Other service activities
# 4         Others      PC - Public Companies    Other service activities
#
#                          TARGET ISSUE_CHEQUES    Age  Tenure  NO_OF_DEPENDENTS
# ...

# %%
recommend_data.shape
# Out:
# (1780883, 12)

# %%
recommend_data
# Out:
#          Unnamed: 0  CUSTOMER_ID                   DESCRIPTION  GENDER  \
# 0                 0      1000764  AC Corporate Current Account  Others
# 1                 1      1001468  AC Corporate Current Account  Others
# 2                 2      1006782  AC Corporate Current Account  Others
# 3                 3      1011339  AC Corporate Current Account  Others
# 4                 4      1015944  AC Corporate Current Account  Others
# ...             ...          ...                           ...     ...
# 1780878     1780878      1770578         Zamuka Mugore Account  FEMALE
# 1780879     1780879      1771203         Zamuka Mugore Account  FEMALE
# 1780880     1780880      1772476         Zamuka Mugore Account  FEMALE
# 1780881     1780881      1773943         Zamuka Mugore Account  FEMALE
# 1780882     1780882      1780320         Zamuka Mugore Account  FEMALE
#
#         MARITAL_STATUS                     SECTOR  \
# 0               Others                 SSA - RSSB
# ...

# %%
last = recommend_data.loc[recommend_data['CUSTOMER_ID']==1053110]
last
# Out:
#          Unnamed: 0  CUSTOMER_ID                 DESCRIPTION GENDER  \
# 13929         13929      1053110                     BK Yacu   MALE
# 150489       150489      1053110                     BK Yacu   MALE
# 319480       319480      1053110         CLASSIC CREDIT CARD   MALE
# 533487       533487      1053110                          IB   MALE
# 626681       626681      1053110                          IB   MALE
# 714707       714707      1053110                       IKOFI   MALE
# 777918       777918      1053110                       IKOFI   MALE
# 867982       867982      1053110  Individual Current account   MALE
# 1145124     1145124      1053110                  Mobile App   MALE
# 1260054     1260054      1053110                  Mobile App   MALE
# 1375199     1375199      1053110                   Mobiserve   MALE
# 1504381     1504381      1053110                   Mobiserve   MALE
#
#         MARITAL_STATUS       SECTOR                            INDUSTRY  \
# ...

# %%
df.loc[df ['col1'] == value]
