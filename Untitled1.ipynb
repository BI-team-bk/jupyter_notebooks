# %%
import pandas as pd 
import numpy as np 
import glob
import json

# %%
df = pd.read_excel('products_sample.xlsx')
grouped = df.groupby('Product_Name').nunique()
grouped
# Out:
#                                Unnamed: 0.1  Unnamed: 0  Customer_ID  \
# Product_Name
# BKQuick simple saving account             2           2            2
# CHARGED.OFF.LOAN                          1           1            1
# Cash Extra Savings                        1           1            1
# INDIVIDUAL.FIXEDEP                        2           2            2
# Individual Current account               20          20           20
# NGO Account                               1           1            1
# Pensionner Current                        3           3            3
# SME Current Account                       5           5            5
# Special Savings Account                   2           2            2
# Student savings                           1           1            1
# UNSECURED.PERSONAL.CLIENT                 5           5            5
# Write off acct                            7           7            7
#
# ...

# %%
# df

# %%
# df_visuals = df[['Customer_ID','Product_Name']]
# df_visuals

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_visuals['Product_Name'],df_visuals['Customer_ID'])

# %%
df_visuals = df_visuals.head(10)
plt.scatter(df_visuals['Customer_ID'], df_visuals['Product_Name'])
plt.xlabel('Product_Name here')
plt.ylabel('Customer_ID here')
plt.title('graph ')
plt.show()

# %%
import seaborn as sns

# %%
df_sns = df[['Customer_ID','Age']]
df_sns = df_sns.head(10)
sns.lineplot( data=df_sns.drop(['Customer_ID'],axis=1))
# plt.xlabel('Age here')
# plt.ylabel('Customer_ID here')
plt.title('graph ')
plt.show()

# %%
import numpy as np

# Create a sample dataset with random values
data = np.random.randn(1000)

# Draw a histogram plot of the data
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
data = pd.DataFrame({'x': np.random.randn(100), 'y': np.random.randn(100)})

# Draw a scatter plot of the data
sns.scatterplot(x='x', y='y', data=data)
# Out:
# <Axes: xlabel='x', ylabel='y'>
