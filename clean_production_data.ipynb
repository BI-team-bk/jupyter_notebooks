# %%
import pandas as pd

# %%
file_path = r"C:/Users/user/Documents/cross-selling/cross-selling/Cross-selling-/CrossSelling_project/recommendation.csv"

# %%
df = pd.read_csv(file_path)
df.shape
# Out:
# (253131, 6)

# %%
df
# Out:
#         Unnamed: 0      id  customer_id        used_products  \
# 0                0       1    1000001.0  SME Current Account
# 1                1       2    1000001.0                  NaN
# 2                2       3    1000001.0                  NaN
# 3                3       4    1000001.0                  NaN
# 4                4       5    1000001.0                  NaN
# ...            ...     ...          ...                  ...
# 253126      253126  253127    1025198.0                  NaN
# 253127      253127  253128    1025198.0                  NaN
# 253128      253128  253129    1025198.0                  NaN
# 253129      253129  253130    1025198.0                  NaN
# 253130      253130  253131    1025198.0                  NaN
#
#                  recommended_products  rank
# 0                            Checques   1.0
# 1                                  IB   2.0
# 2                          Mobile App   3.0
# 3                  Visa Classic Debit   4.0
# ...

# %%
df = df.reset_index(drop=True).drop(columns=['Unnamed: 0'])
df
# Out:
#             id  customer_id        used_products  \
# 0            1    1000001.0  SME Current Account
# 1            2    1000001.0                  NaN
# 2            3    1000001.0                  NaN
# 3            4    1000001.0                  NaN
# 4            5    1000001.0                  NaN
# ...        ...          ...                  ...
# 253126  253127    1025198.0                  NaN
# 253127  253128    1025198.0                  NaN
# 253128  253129    1025198.0                  NaN
# 253129  253130    1025198.0                  NaN
# 253130  253131    1025198.0                  NaN
#
#                  recommended_products  rank
# 0                            Checques   1.0
# 1                                  IB   2.0
# 2                          Mobile App   3.0
# 3                  Visa Classic Debit   4.0
# 4                           Mobiserve   5.0
# ...                               ...   ...
# 253126                             IB  11.0
# ...

# %%
df.to_csv('recommendation_data.csv', index=False)
df.shape
# Out:
# (253131, 5)

# %%
pd.set_option('display.max_columns',10000000)
pd.set_option('display.max_rows',10000000)

# %%
df
